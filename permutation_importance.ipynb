# %% [markdown]
# # Permutation Importance

# %% [markdown]
# ### Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
import gc
import logging
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from eli5.sklearn import PermutationImportance
import lightgbm as lgb
import eli5
import datetime
import os

# %% [markdown]
# ### Logging

# %%
if not os.path.exists('logs'):
    os.makedirs('logs')

LOG_NAME = 'logs/Permutation_importances.log'
logging.basicConfig(filename=LOG_NAME, level=logging.WARNING, format='%(asctime)s %(message)s')
logging.warning("")
logging.warning("##### New Permutation Importance Study #####")

# %% [markdown]
# ### Data

# %%
logging.warning("Studying most important features")

# %%
train = pd.read_csv('data/reduce_train.csv')

# %%
_target = 'accuracy_group'
_id = 'installation_id'

# %%
for i, j in zip(train.columns, train.iloc[0,:]):
    print(i, j)
# Out:
# Clip 11
# Activity 3
# Assessment 0
# Game 4
# acc_Mushroom Sorter (Assessment) -1.0
# acc_Cauldron Filler (Assessment) -1.0
# acc_Chest Sorter (Assessment) -1.0
# acc_Bird Measurer (Assessment) -1.0
# acc_Cart Balancer (Assessment) -1.0
# 2050 6
# 4100 0
# 4230 0
# 5000 0
# 4235 0
# 2060 0
# 4110 0
# 5010 0
# 2070 0
# 2075 0
# 2080 4
# 2081 1
# 2083 2
# 3110 77
# 4010 4
# 3120 7
# 3121 9
# 4020 92
# 4021 14
# 4022 31
# 4025 19
# 4030 121
# 4031 0
# 3010 79
# 4035 1
# 4040 0
# 3020 7
# 3021 9
# 4045 0
# 2000 18
# 4050 0
# 2010 0
# 2020 20
# 4070 94
# 2025 4
# 2030 18
# 4080 0
# 2035 0
# 2040 6
# 4090 4
# 4220 0
# 4095 0
# 16dffff1 0
# 0a08139c 0
# 3babcb9b 0
# 48349b14 0
# 73757a5e 6
# 160654fd 0
# ab3136ba 0
# a8a78786 0
# 46b50ba8 0
# cf82af56 14
# 907a054b 0
# 28a4eb9a 0
# a7640a16 0
# 5e812b27 21
# 6088b756 0
# ac92046e 3
# 736f9581 0
# 1cc7cfca 27
# d185d3ea 0
# 1bb5fbdb 19
# e7e44842 0
# bd612267 0
# d3f1e122 0
# 4bb2f698 0
# 8d84fa81 0
# 3d0b9317 0
# d122731b 0
# 3bf1cf26 0
# 93b353f2 0
# d2278a3b 0
# 832735e1 0
# 83c6c409 0
# 795e4a37 0
# b120f2ac 4
# 3323d7e9 0
# d38c2fd7 0
# 3b2048ee 0
# 37c53127 6
# f28c589a 0
# f806dc10 0
# dcb55a27 0
# 9ce586dd 0
# 15a43e5b 0
# 1340b8d7 0
# 88d4a5be 0
# 6bf9e3e1 0
# 6077cc36 0
# a44b10dc 13
# 91561152 0
# 2c4e6db0 5
# 14de4c5d 0
# 923afab1 0
# c51d8688 0
# d3268efa 0
# c189aaf2 0
# a8efe47b 0
# e37a2b78 0
# 71fe8f75 0
# a592d54e 0
# 8fee50e2 0
# beb0a7b9 15
# 15f99afc 0
# 461eace6 0
# f3cd5473 0
# d2659ab4 0
# 9e34ea74 0
# 74e5f8a7 0
# cb1178ad 0
# 1beb320a 0
# 30614231 0
# eb2c19cd 0
# 7040c096 1
# 565a3990 0
# f5b8c21a 0
# b2e5b0f1 0
# bd701df8 0
# 7d093bf9 0
# 392e14df 0
# 27253bdc 11
# 86ba578b 0
# 5de79a6a 0
# d45ed6a1 4
# 16667cc5 0
# 363c86c9 0
# 90d848e0 0
# 08fd73f3 15
# db02c830 0
# a16a373e 0
# ad2fc29c 0
# 28ed704e 0
# 2fb91ec1 0
# 28f975ea 0
# bfc77bd6 0
# 3edf6747 0
# a29c5338 0
# 9b01374f 1
# e4d32835 0
# 4901243f 1
# 5f5b2617 0
# cc5087a3 0
# 3dcdda7f 0
# cf7638f3 0
# acf5c23f 0
# bdf49a58 0
# c74f40cd 0
# f71c4741 15
# 262136f4 0
# 08ff79ad 0
# bbfe0445 17
# 5c2f29ca 0
# 1cf54632 0
# 0db6d71d 0
# 4d911100 0
# 8ac7cce4 0
# 2a512369 0
# f56e0afc 0
# e3ff61fb 0
# 9b23e8ee 0
# 90ea0bac 0
# 2dc29e21 26
# 1575e76c 0
# 8f094001 0
# 6f4adc4b 0
# b74258a0 0
# ecc6157f 0
# c58186bf 0
# 51102b85 0
# 8af75982 0
# bcceccc6 0
# 9c5ef70c 0
# 804ee27f 0
# 65abac75 0
# 9ed8f6da 0
# 562cec5f 0
# 58a0de5c 0
# cb6010f8 0
# 499edb7c 0
# 37ee8496 0
# 6c930e6e 0
# 731c0cbe 0
# 19967db1 0
# 5348fd84 0
# fbaf3456 0
# bc8f2793 0
# 763fc34e 0
# 6d90d394 1
# 26a5a3dd 0
# 3dfd4aa4 0
# e79f3763 0
# e9c52111 0
# ecaab346 0
# 17113b36 0
# cdd22e43 0
# 5a848010 4
# 756e5507 0
# dcb1663e 0
# 0086365d 0
# 25fa8af4 0
# 1b54d27f 0
# 3ee399c3 0
# 5290eab1 0
# b80e5e84 0
# 37937459 2
# 3bb91ced 0
# 92687c59 0
# 7fd1ac25 0
# 7ec0c298 0
# 26fd2d99 15
# c277e121 4
# 47026d5f 0
# e080a381 0
# 55115cbd 0
# 63f13dd7 0
# 06372577 0
# c6971acf 0
# 7ad3efc6 0
# b2dba42b 20
# d2e9262e 0
# 0330ab6a 0
# ad148f58 0
# 2230fab4 0
# b7530680 0
# a8876db3 0
# 587b5989 42
# 69fdac0a 0
# 8b757ab8 0
# d88e8f25 3
# 1996c610 0
# 0d18d96c 0
# d06f75b5 0
# 3bb91dda 0
# 003cd2ee 0
# 71e712d8 0
# 29f54413 0
# 46cd75b4 0
# 7f0836bf 0
# 9ee1c98c 14
# 2b058fe3 0
# b5053438 0
# e4f1efe6 0
# a0faea5d 0
# 2ec694de 0
# f93fc684 0
# f32856e4 0
# 4c2ec19f 0
# c2baf0bd 0
# f54238ee 0
# e57dd7af 0
# 5f0eb72c 0
# e694a35b 23
# 30df3273 0
# 15eb4a7d 0
# bb3e370b 0
# 33505eae 0
# 84b0e0c8 0
# 56cd3b43 17
# d3640339 0
# e64e2cfd 0
# 7ab78247 0
# c7fe2a55 0
# 99ea62f3 0
# d9c005dd 0
# 65a38bf7 0
# 7525289a 0
# 1af8be29 0
# a1e4395d 0
# 5e109ec3 0
# 0ce40006 0
# a1bbe385 0
# d51b1749 0
# 47f43a44 0
# ca11f653 3
# 9554a50b 0
# 9d29771f 0
# 38074c54 0
# 01ca3a3c 0
# 51311d7a 0
# f50fc6c1 0
# c0415e5c 0
# 6043a2b4 2
# a5e9da97 0
# df4fe8b6 0
# fd20ea40 0
# 77ead60d 0
# 45d01abe 0
# 857f21c0 0
# fcfdffb6 31
# 0d1da71f 0
# abc5811c 0
# 4d6737eb 0
# 6f8106d9 0
# 77c76bc5 0
# 76babcde 0
# 86c924c4 0
# df4940d3 0
# 4a4c3d21 0
# 1325467d 18
# 3afb49e6 0
# 6c517a88 0
# a5be6304 0
# 17ca3959 0
# 6aeafed4 0
# 222660ff 0
# ea296733 0
# 1f19558b 3
# 598f4598 19
# 5859dfb6 0
# 85d1b0de 0
# f6947f54 0
# b7dc8128 3
# 070a5291 0
# 00c73085 0
# 884228c8 7
# 31973d56 0
# 02a42007 23
# 5154fc30 0
# 7961e599 0
# 792530f8 0
# 5dc079d8 0
# cfbd47c8 0
# 828e68f9 0
# 93edfe2e 0
# 709b1251 0
# 99abe2bb 0
# 5be391b5 0
# e7561dd2 0
# daac11b0 3
# 2b9272f4 6
# 9de5e594 0
# e5c9df6f 0
# d02b7a8e 1
# 3afde5dd 0
# a8cc6fec 0
# 7da34a02 0
# 04df9b66 0
# 6f4bd64e 0
# 7dfe6d8a 0
# 2dcad279 0
# 3d63345e 0
# 7d5c30a2 0
# 67aa2ada 0
# 250513af 0
# 1c178d24 0
# 36fa3ebe 0
# 9d4e7b25 0
# 85de926c 0
# 29a42aea 0
# 67439901 0
# 7cf1bc53 0
# a52b92d5 0
# c7f7f0e1 0
# 3393b68b 0
# a76029ee 0
# c54cf6c5 0
# 155f62a4 0
# a6d66e51 0
# ecc36b7f 0
# c1cac9a2 1
# 4ef8cdd3 0
# 56bcd38d 0
# 90efca10 0
# 3a4be871 0
# 56817e2b 0
# 7372e1a5 0
# 1375ccb7 0
# 0413e89d 0
# 2a444e03 0
# d88ca108 0
# 3ccd3f02 0
# 9e6b7fb5 0
# ab4ec3a4 0
# b1d5101d 0
# 47efca07 0
# 49ed92e9 0
# 84538528 7
# 28520915 0
# 29bdd9ba 0
# 611485c5 0
# 4074bac2 0
# c7128948 0
# 9b4001e4 0
# e04fb33d 0
# 05ad839b 0
# 8d748b58 0
# 363d3849 12
# 44cb4907 0
# 13f56524 0
# e5734469 0
# 77261ab5 1
# 5b49460a 0
# de26c3a6 18
# 895865f3 0
# c952eb01 0
# 89aace00 0
# 9e4c8c7b 11
# 37db1c2f 0
# 4b5efe37 3
# 87d743c1 0
# 5d042115 50
# f7e47413 15
# 4e5fc6f5 0
# 119b5b02 0
# 4a09ace1 2
# 6f445b57 0
# 6cf7d25c 0
# 5e3ea25a 0
# a1192f43 0
# 5c3d2b2f 18
# 3ddc79c3 0
# 022b4259 0
# dcaede90 6
# 15ba1109 0
# b012cd7f 0
# ea321fb1 0
# 8d7e386c 0
# a2df0760 0
# 532a2afb 0
# b88f38da 15
# 3d8c61b0 0
# 7423acbc 0
# 3bfd1a65 0
# ec138c1c 0
# e720d930 0
# 53c6e11a 0
# 2050_g 6
# 4100_g 0
# 4230_g 0
# 5000_g 0
# 4235_g 0
# 2060_g 0
# 4110_g 0
# 5010_g 0
# 2070_g 0
# 2075_g 0
# 2080_g 4
# 2081_g 1
# 2083_g 2
# 3110_g 26
# 4010_g 4
# 3120_g 7
# 3121_g 9
# 4020_g 44
# 4021_g 0
# 4022_g 0
# 4025_g 0
# 4030_g 27
# 4031_g 0
# 3010_g 27
# 4035_g 1
# 4040_g 0
# 3020_g 7
# 3021_g 9
# 4045_g 0
# 2000_g 4
# 4050_g 0
# 2010_g 0
# 2020_g 20
# 4070_g 56
# 2025_g 4
# 2030_g 18
# 4080_g 0
# 2035_g 0
# 2040_g 6
# 4090_g 2
# 4220_g 0
# 4095_g 0
# 2050_A 0
# 4100_A 0
# 4230_A 0
# 5000_A 0
# 4235_A 0
# 2060_A 0
# 4110_A 0
# 5010_A 0
# 2070_A 0
# 2075_A 0
# 2080_A 0
# 2081_A 0
# 2083_A 0
# 3110_A 51
# 4010_A 0
# 3120_A 0
# 3121_A 0
# 4020_A 48
# 4021_A 14
# 4022_A 31
# 4025_A 19
# 4030_A 94
# 4031_A 0
# 3010_A 52
# 4035_A 0
# 4040_A 0
# 3020_A 0
# 3021_A 0
# 4045_A 0
# 2000_A 3
# 4050_A 0
# 2010_A 0
# 2020_A 0
# 4070_A 38
# 2025_A 0
# 2030_A 0
# 4080_A 0
# 2035_A 0
# 2040_A 0
# 4090_A 2
# 4220_A 0
# 4095_A 0
# Mushroom Sorter (Assessment) 0
# Happy Camel 0
# Egg Dropper (Activity) 0
# Tree Top City - Level 2 1
# Magma Peak - Level 1 1
# Scrub-A-Dub 131
# Lifting Heavy Things 0
# Treasure Map 0
# Welcome to Lost Lagoon! 2
# Magma Peak - Level 2 0
# Costume Box 2
# Balancing Act 0
# Crystal Caves - Level 3 0
# Rulers 0
# Pan Balance 0
# Bird Measurer (Assessment) 0
# Leaf Leader 0
# Tree Top City - Level 3 0
# Pirate's Tale 1
# Chicken Balancer (Activity) 0
# Heavy, Heavier, Heaviest 0
# Fireworks (Activity) 84
# Dino Drink 0
# Watering Hole (Activity) 0
# All Star Sorting 153
# Flower Waterer (Activity) 166
# Dino Dive 0
# Honey Cake 0
# 12 Monkeys 1
# Bottle Filler (Activity) 0
# Sandcastle Builder (Activity) 102
# Ordering Spheres 1
# Chow Time 0
# Slop Problem 1
# Cart Balancer (Assessment) 0
# Tree Top City - Level 1 1
# Cauldron Filler (Assessment) 0
# Chest Sorter (Assessment) 0
# Bubble Bath 0
# Crystal Caves - Level 1 0
# Crystal Caves - Level 2 0
# Air Show 0
# Bug Measurer (Activity) 0
# Crystals Rule 0
# Dino Dive_3010 0
# Cauldron Filler (Assessment)_4040 0
# Chest Sorter (Assessment)_4035 0
# Scrub-A-Dub_2080 4
# Bird Measurer (Assessment)_4040 0
# Chest Sorter (Assessment)_2000 0
# Dino Drink_4031 0
# Bottle Filler (Activity)_4090 0
# Dino Dive_4090 0
# Bird Measurer (Assessment)_2000 0
# Sandcastle Builder (Activity)_3010 20
# Air Show_3021 0
# Dino Dive_3121 0
# Bug Measurer (Activity)_2000 0
# Chest Sorter (Assessment)_4040 0
# Bottle Filler (Activity)_3010 0
# Leaf Leader_3010 0
# Magma Peak - Level 1_2000 1
# Crystals Rule_2000 0
# Scrub-A-Dub_3110 15
# Happy Camel_3121 0
# Flower Waterer (Activity)_2000 1
# Pan Balance_4030 0
# Mushroom Sorter (Assessment)_4080 0
# Cauldron Filler (Assessment)_4020 0
# Happy Camel_4040 0
# 12 Monkeys_2000 1
# Dino Drink_3110 0
# Leaf Leader_3021 0
# Bird Measurer (Assessment)_4025 0
# Happy Camel_2030 0
# Bird Measurer (Assessment)_4080 0
# Bubble Bath_4235 0
# Mushroom Sorter (Assessment)_3010 0
# Chest Sorter (Assessment)_4025 0
# Air Show_2070 0
# All Star Sorting_4010 3
# Chow Time_4010 0
# Bubble Bath_4045 0
# Happy Camel_3020 0
# Mushroom Sorter (Assessment)_4100 0
# Cart Balancer (Assessment)_4040 0
# Bottle Filler (Activity)_2020 0
# Pan Balance_3020 0
# Bubble Bath_3121 0
# Bottle Filler (Activity)_2000 0
# Mushroom Sorter (Assessment)_4090 0
# Dino Dive_3110 0
# Bottle Filler (Activity)_4070 0
# Pan Balance_2000 0
# Dino Drink_2075 0
# Cart Balancer (Assessment)_4020 0
# Bubble Bath_3021 0
# Happy Camel_2080 0
# Cauldron Filler (Assessment)_4070 0
# Sandcastle Builder (Activity)_4035 0
# Crystals Rule_2020 0
# Dino Dive_3021 0
# Mushroom Sorter (Assessment)_4040 0
# Egg Dropper (Activity)_2020 0
# Bubble Bath_4020 0
# Bug Measurer (Activity)_3010 0
# Air Show_4070 0
# Egg Dropper (Activity)_4080 0
# Cauldron Filler (Assessment)_4035 0
# Cauldron Filler (Assessment)_3121 0
# Dino Drink_2000 0
# Dino Drink_3010 0
# Pan Balance_3021 0
# Fireworks (Activity)_4030 23
# Tree Top City - Level 1_2000 1
# Scrub-A-Dub_4080 0
# Bubble Bath_3020 0
# Chow Time_3020 0
# Pan Balance_2020 0
# Mushroom Sorter (Assessment)_3120 0
# Bug Measurer (Activity)_4070 0
# Bug Measurer (Activity)_3110 0
# Air Show_4110 0
# Pan Balance_3110 0
# Scrub-A-Dub_4010 1
# Bottle Filler (Activity)_2030 0
# Cart Balancer (Assessment)_4035 0
# All Star Sorting_2025 4
# Air Show_4100 0
# Happy Camel_4090 0
# Dino Drink_3021 0
# Mushroom Sorter (Assessment)_4030 0
# Egg Dropper (Activity)_2000 0
# Crystals Rule_3010 0
# Happy Camel_2000 0
# Chest Sorter (Assessment)_3010 0
# Mushroom Sorter (Assessment)_3020 0
# All Star Sorting_3010 12
# Air Show_2075 0
# Scrub-A-Dub_2081 1
# Sandcastle Builder (Activity)_4021 14
# Chow Time_2030 0
# Bug Measurer (Activity)_4025 0
# Watering Hole (Activity)_4020 0
# Fireworks (Activity)_2000 1
# All Star Sorting_3021 3
# All Star Sorting_2030 3
# Sandcastle Builder (Activity)_2000 1
# Sandcastle Builder (Activity)_4020 7
# Rulers_2000 0
# Bird Measurer (Assessment)_3120 0
# Scrub-A-Dub_2040 6
# Scrub-A-Dub_3021 6
# Pan Balance_4025 0
# Sandcastle Builder (Activity)_3110 19
# Pan Balance_3010 0
# Bird Measurer (Assessment)_4020 0
# Cauldron Filler (Assessment)_2000 0
# Bird Measurer (Assessment)_3010 0
# Dino Dive_2030 0
# All Star Sorting_2020 5
# Scrub-A-Dub_2050 6
# Chicken Balancer (Activity)_4080 0
# Bird Measurer (Assessment)_3021 0
# Pan Balance_4090 0
# Leaf Leader_3121 0
# Fireworks (Activity)_3110 15
# Bird Measurer (Assessment)_4110 0
# Pan Balance_2010 0
# Cart Balancer (Assessment)_4080 0
# Happy Camel_4045 0
# Pan Balance_4080 0
# Bird Measurer (Assessment)_2020 0
# Bug Measurer (Activity)_4080 0
# All Star Sorting_4090 2
# Dino Drink_3020 0
# Chest Sorter (Assessment)_3120 0
# Bubble Bath_4070 0
# Bird Measurer (Assessment)_4100 0
# Dino Drink_2060 0
# Chow Time_4080 0
# Dino Drink_4010 0
# Chicken Balancer (Activity)_4090 0
# Chest Sorter (Assessment)_4100 0
# Treasure Map_2000 0
# Bubble Bath_4095 0
# Crystals Rule_3120 0
# Chow Time_4095 0
# Chow Time_2020 0
# Dino Drink_3120 0
# Dino Drink_3121 0
# Leaf Leader_4090 0
# Fireworks (Activity)_4080 0
# Bubble Bath_2030 0
# Scrub-A-Dub_2030 15
# Mushroom Sorter (Assessment)_4035 0
# Leaf Leader_2030 0
# All Star Sorting_4035 1
# Dino Dive_2060 0
# Chicken Balancer (Activity)_4030 0
# Bottle Filler (Activity)_4020 0
# Ordering Spheres_2000 1
# Chest Sorter (Assessment)_4020 0
# Fireworks (Activity)_4090 0
# Happy Camel_4070 0
# Heavy, Heavier, Heaviest_2000 0
# Chow Time_3010 0
# Dino Drink_4030 0
# Cart Balancer (Assessment)_3021 0
# Cauldron Filler (Assessment)_4025 0
# Flower Waterer (Activity)_4070 13
# Happy Camel_3021 0
# Fireworks (Activity)_4070 7
# Watering Hole (Activity)_4021 0
# Leaf Leader_4080 0
# Balancing Act_2000 0
# Cart Balancer (Assessment)_3010 0
# Leaf Leader_2000 0
# Cauldron Filler (Assessment)_3021 0
# Chicken Balancer (Activity)_3010 0
# Mushroom Sorter (Assessment)_3110 0
# Happy Camel_4010 0
# Bird Measurer (Assessment)_4090 0
# All Star Sorting_3020 4
# Chicken Balancer (Activity)_2000 0
# Air Show_3020 0
# Crystal Caves - Level 1_2000 0
# Cauldron Filler (Assessment)_4030 0
# Leaf Leader_2020 0
# Chest Sorter (Assessment)_3021 0
# Bottle Filler (Activity)_4030 0
# Bird Measurer (Assessment)_3121 0
# Dino Drink_4070 0
# Bubble Bath_3010 0
# Bubble Bath_2025 0
# Air Show_3110 0
# Mushroom Sorter (Assessment)_4020 0
# Chow Time_3110 0
# Bubble Bath_3110 0
# Flower Waterer (Activity)_3110 17
# Tree Top City - Level 3_2000 0
# Scrub-A-Dub_2083 2
# Cart Balancer (Assessment)_2030 0
# Leaf Leader_2075 0
# Watering Hole (Activity)_4070 0
# Cart Balancer (Assessment)_4030 0
# All Star Sorting_4020 26
# Air Show_2030 0
# Leaf Leader_4010 0
# Air Show_2060 0
# Mushroom Sorter (Assessment)_4025 0
# Mushroom Sorter (Assessment)_3021 0
# Pan Balance_2030 0
# Mushroom Sorter (Assessment)_2010 0
# Chest Sorter (Assessment)_4030 0
# Leaf Leader_2060 0
# Cauldron Filler (Assessment)_3120 0
# Air Show_4010 0
# Crystals Rule_2010 0
# Bug Measurer (Activity)_4035 0
# Crystals Rule_3121 0
# Sandcastle Builder (Activity)_4080 0
# Happy Camel_4095 0
# Scrub-A-Dub_3120 3
# Flower Waterer (Activity)_4080 0
# Air Show_3120 0
# Air Show_3010 0
# Watering Hole (Activity)_2000 0
# Bottle Filler (Activity)_4080 0
# All Star Sorting_3110 11
# Pan Balance_4035 0
# Crystals Rule_3021 0
# Scrub-A-Dub_4020 18
# Cauldron Filler (Assessment)_2020 0
# Flower Waterer (Activity)_4030 50
# Scrub-A-Dub_4090 0
# Flower Waterer (Activity)_4025 19
# Costume Box_2000 2
# Mushroom Sorter (Assessment)_2000 0
# Crystals Rule_4010 0
# Chow Time_4020 0
# Tree Top City - Level 2_2000 1
# Egg Dropper (Activity)_3010 0
# Chest Sorter (Assessment)_4080 0
# Bird Measurer (Assessment)_3020 0
# Flower Waterer (Activity)_4022 31
# Bird Measurer (Assessment)_2030 0
# All Star Sorting_4095 0
# Bubble Bath_4220 0
# Cart Balancer (Assessment)_3120 0
# Scrub-A-Dub_3020 3
# Crystal Caves - Level 2_2000 0
# Chest Sorter (Assessment)_2030 0
# Leaf Leader_3020 0
# Bug Measurer (Activity)_4090 0
# Sandcastle Builder (Activity)_4030 21
# Pan Balance_4070 0
# Air Show_2000 0
# Air Show_3121 0
# Pan Balance_4100 0
# Cauldron Filler (Assessment)_3020 0
# Crystals Rule_4070 0
# Scrub-A-Dub_3010 15
# Happy Camel_4035 0
# Dino Drink_2020 0
# Watering Hole (Activity)_4025 0
# Bird Measurer (Assessment)_2010 0
# Bird Measurer (Assessment)_4030 0
# Watering Hole (Activity)_3110 0
# Watering Hole (Activity)_3010 0
# Flower Waterer (Activity)_4090 0
# Cart Balancer (Assessment)_4090 0
# Mushroom Sorter (Assessment)_2020 0
# Chow Time_4090 0
# Bubble Bath_3120 0
# Chest Sorter (Assessment)_2020 0
# Chow Time_2000 0
# Honey Cake_2000 0
# Sandcastle Builder (Activity)_4070 18
# Crystals Rule_4050 0
# Leaf Leader_3120 0
# Chow Time_3121 0
# Bubble Bath_4090 0
# Dino Dive_2020 0
# Crystals Rule_3110 0
# Crystals Rule_4090 0
# All Star Sorting_4030 27
# All Star Sorting_4080 0
# Pan Balance_3120 0
# Cart Balancer (Assessment)_3121 0
# Mushroom Sorter (Assessment)_2025 0
# Chest Sorter (Assessment)_3020 0
# Pirate's Tale_2000 1
# Cart Balancer (Assessment)_2020 0
# Bubble Bath_2080 0
# Dino Drink_4020 0
# Dino Dive_4010 0
# Chow Time_3120 0
# Dino Drink_2030 0
# Dino Drink_4090 0
# Fireworks (Activity)_4020 23
# Mushroom Sorter (Assessment)_2030 0
# Bottle Filler (Activity)_2010 0
# Bottle Filler (Activity)_4035 0
# Crystals Rule_3020 0
# Chow Time_3021 0
# Egg Dropper (Activity)_4070 0
# Happy Camel_3010 0
# Mushroom Sorter (Assessment)_3121 0
# Crystals Rule_2030 0
# Leaf Leader_2070 0
# Air Show_4020 0
# Scrub-A-Dub_4070 14
# Cauldron Filler (Assessment)_4100 0
# All Star Sorting_4070 42
# Bug Measurer (Activity)_4030 0
# Air Show_4090 0
# Dino Drink_2070 0
# Cart Balancer (Assessment)_2010 0
# Bird Measurer (Assessment)_4035 0
# Happy Camel_4020 0
# Egg Dropper (Activity)_3110 0
# Chicken Balancer (Activity)_4022 0
# Lifting Heavy Things_2000 0
# Dino Dive_4080 0
# Cauldron Filler (Assessment)_4080 0
# Bubble Bath_4080 0
# All Star Sorting_3121 3
# Mushroom Sorter (Assessment)_4070 0
# Happy Camel_4080 0
# Happy Camel_4030 0
# Leaf Leader_3110 0
# Dino Dive_2000 0
# Cauldron Filler (Assessment)_2010 0
# Watering Hole (Activity)_5010 0
# Watering Hole (Activity)_4090 0
# Cart Balancer (Assessment)_3020 0
# Happy Camel_3120 0
# Happy Camel_2081 0
# Cart Balancer (Assessment)_4100 0
# Welcome to Lost Lagoon!_2000 2
# Cauldron Filler (Assessment)_3110 0
# Bird Measurer (Assessment)_4070 0
# Happy Camel_3110 0
# Chest Sorter (Assessment)_3121 0
# Bubble Bath_2000 0
# Cart Balancer (Assessment)_2000 0
# Egg Dropper (Activity)_4025 0
# Egg Dropper (Activity)_4090 0
# Mushroom Sorter (Assessment)_2035 0
# Air Show_2020 0
# Crystal Caves - Level 3_2000 0
# Cauldron Filler (Assessment)_4090 0
# Dino Dive_4070 0
# Pan Balance_3121 0
# Pan Balance_4010 0
# Cauldron Filler (Assessment)_3010 0
# Dino Dive_2070 0
# Bird Measurer (Assessment)_3110 0
# Flower Waterer (Activity)_3010 17
# Slop Problem_2000 1
# Dino Drink_4080 0
# Air Show_4080 0
# Sandcastle Builder (Activity)_2010 0
# Watering Hole (Activity)_2010 0
# Bubble Bath_4230 0
# Chow Time_4070 0
# Bubble Bath_2020 0
# Leaf Leader_4095 0
# Chest Sorter (Assessment)_3110 0
# Bottle Filler (Activity)_3110 0
# Chicken Balancer (Activity)_4035 0
# All Star Sorting_3120 4
# Pan Balance_4020 0
# Bubble Bath_4010 0
# Scrub-A-Dub_3121 6
# Watering Hole (Activity)_5000 0
# Cart Balancer (Assessment)_4070 0
# All Star Sorting_2000 3
# Leaf Leader_4070 0
# Chest Sorter (Assessment)_4090 0
# Bubble Bath_4040 0
# Scrub-A-Dub_2000 1
# Magma Peak - Level 2_2000 0
# Cauldron Filler (Assessment)_2030 0
# Happy Camel_2083 0
# Fireworks (Activity)_3010 15
# Flower Waterer (Activity)_4020 18
# Cart Balancer (Assessment)_3110 0
# Leaf Leader_4020 0
# Dino Dive_3120 0
# Happy Camel_2020 0
# Egg Dropper (Activity)_4020 0
# Chicken Balancer (Activity)_4020 0
# Dino Dive_3020 0
# Chow Time_4030 0
# Chicken Balancer (Activity)_3110 0
# Chow Time_4035 0
# Dino Dive_4020 0
# Chest Sorter (Assessment)_2010 0
# Bubble Bath_2083 0
# Chest Sorter (Assessment)_4070 0
# Sandcastle Builder (Activity)_4090 2
# Crystals Rule_4020 0
# Bubble Bath_2035 0
# Chicken Balancer (Activity)_4070 0
# Scrub-A-Dub_2020 15
# installation_session_count 18
# hour 5
# weekday 1
# var_event_code 24
# var_event_id 56
# var_title 14
# var_title_event_code 64
# installation_id 0006a69f
# session_title 0
# accumulated_correct_attempts 0
# accumulated_uncorrect_attempts 0
# game_sum_event_count 284
# Activity_sum_event_count 284
# duration_mean 0.0
# duration_std 0.0
# Clip_duration_mean 48.36363636363637
# Clip_duration_std 29.155609868031558
# Activity_duration_mean 114.66666666666669
# Activity_duration_std 34.89348872720462
# Game_duration_mean 69.5
# Game_duration_std 37.95062581829185
# accumulated_accuracy 0.0
# accuracy_group 3
# 0 0
# 1 0
# 2 0
# 3 0
# accumulated_accuracy_group 0.0
# accumulated_actions 647

# %%
select_cols = [x for x in train.columns if x not in [_target, _id]]

# %% [markdown]
# #### RandomForest

# %%
logging.warning("Model used to PermitationImportance: {}".format('Random Forest'))

# %%
model_rf = RandomForestClassifier(n_estimators=200, oob_score=True, n_jobs=-1,
                                  random_state=42, max_depth=5, criterion='entropy')

# %%
X = train[select_cols]
y = train[_target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=True, random_state=42, verbose=0,
#                        warm_start=False)

# %%
logging.warning("Params: {}".format(str(model_rf.get_params())))

# %% [markdown]
# ### Permitation Importance

# %%
perm_rf = PermutationImportance(model_rf).fit(X_test, y_test)

# %%
# eli5.show_weights(perm_rf,feature_names=X_train.columns.tolist(),
#                   top=500)

# %%
logging.warning("Importances: {}".format(str(perm_rf.feature_importances_)))

# %%
df_perm = pd.DataFrame({'feature': X_train.columns, 'Importance': perm_rf.feature_importances_}).sort_values('Importance', ascending=False)
df_perm.head(20)
# Out:
#                              feature  Importance
# 973                    session_title    0.021406
# 362                         3393b68b    0.002261
# 991       accumulated_accuracy_group    0.001470
# 274                         7525289a    0.001394
# 903   Chest Sorter (Assessment)_3121    0.001319
# 295                         45d01abe    0.001244
# 910     Crystal Caves - Level 3_2000    0.001093
# 531          Crystal Caves - Level 3    0.000980
# 697  Bird Measurer (Assessment)_4100    0.000942
# 986             accumulated_accuracy    0.000942
# 110                         8fee50e2    0.000829
# 6      acc_Chest Sorter (Assessment)    0.000754
# 682  Bird Measurer (Assessment)_3021    0.000754
# 313                         222660ff    0.000716
# 250                         e4f1efe6    0.000716
# 7     acc_Bird Measurer (Assessment)    0.000603
# 825  Bird Measurer (Assessment)_2010    0.000565
# 180                         9c5ef70c    0.000565
# 319                         f6947f54    0.000490
# 35                              3020    0.000452

# %%
today = datetime.date.today()
D = today.strftime('%Y%m%d')

file_name = 'importances/{0}_PermutationImportance_RF.csv'.format(D)

# %%
df_perm.to_csv(file_name, header=True, index=None)

# %%
logging.warning("End")

# %%
df_perm[df_perm.Importance > 0].shape
# Out:
# (168, 2)

# %%
df_perm[df_perm.Importance > 0]['feature'].tolist()
# Out:
# ['session_title',
#  '3393b68b',
#  'accumulated_accuracy_group',
#  '7525289a',
#  'Chest Sorter (Assessment)_3121',
#  '45d01abe',
#  'Crystal Caves - Level 3_2000',
#  'Crystal Caves - Level 3',
#  'Bird Measurer (Assessment)_4100',
#  'accumulated_accuracy',
#  '8fee50e2',
#  'acc_Chest Sorter (Assessment)',
#  'Bird Measurer (Assessment)_3021',
#  '222660ff',
#  'e4f1efe6',
#  'acc_Bird Measurer (Assessment)',
#  'Bird Measurer (Assessment)_2010',
#  '9c5ef70c',
#  'f6947f54',
#  '3020',
#  'Pan Balance_3120',
#  'Cart Balancer (Assessment)_4100',
#  'a592d54e',
#  'Chest Sorter (Assessment)_4030',
#  '0db6d71d',
#  '3020_g',
#  '3120',
#  '070a5291',
#  'Pan Balance',
#  'Welcome to Lost Lagoon!',
#  '38074c54',
#  '363d3849',
#  '12 Monkeys',
#  'Crystal Caves - Level 1_2000',
#  '160654fd',
#  '1c178d24',
#  'Chest Sorter (Assessment)_2030',
#  'Chest Sorter (Assessment)_2010',
#  'Cauldron Filler (Assessment)_2000',
#  '2050',
#  'Leaf Leader_2060',
#  '4090',
#  'Egg Dropper (Activity)_2000',
#  'Mushroom Sorter (Assessment)_2010',
#  '15f99afc',
#  '3afb49e6',
#  'Egg Dropper (Activity)_4070',
#  'Chest Sorter (Assessment)_4040',
#  '5e109ec3',
#  'e7561dd2',
#  'Leaf Leader_3121',
#  'd122731b',
#  'Pan Balance_3020',
#  'accumulated_actions',
#  'Fireworks (Activity)_4090',
#  '3b2048ee',
#  '9b23e8ee',
#  'Cauldron Filler (Assessment)_3120',
#  'Chest Sorter (Assessment)_3021',
#  '4021_A',
#  'Cart Balancer (Assessment)_4020',
#  '2080',
#  'Pan Balance_3010',
#  '907a054b',
#  '7ab78247',
#  '6cf7d25c',
#  '2000',
#  'Assessment',
#  '9ee1c98c',
#  'Mushroom Sorter (Assessment)_2025',
#  "Pirate's Tale",
#  'Flower Waterer (Activity)_4022',
#  '3dcdda7f',
#  'Pan Balance_3110',
#  'Bird Measurer (Assessment)_2020',
#  'Clip_duration_std',
#  'c6971acf',
#  'bd612267',
#  'Cart Balancer (Assessment)_3010',
#  'a5e9da97',
#  '0086365d',
#  '5b49460a',
#  'e9c52111',
#  'cc5087a3',
#  'Activity_sum_event_count',
#  '2025_g',
#  'e080a381',
#  'Crystal Caves - Level 2_2000',
#  'Mushroom Sorter (Assessment)_4040',
#  'All Star Sorting_3110',
#  '71e712d8',
#  'Watering Hole (Activity)_4020',
#  '4230_g',
#  '562cec5f',
#  'f3cd5473',
#  '3010_g',
#  'Chest Sorter (Assessment)_3020',
#  '4100_g',
#  'Bird Measurer (Assessment)_3110',
#  '9ce586dd',
#  '6bf9e3e1',
#  '5d042115',
#  '4070_g',
#  'f54238ee',
#  '91561152',
#  'a5be6304',
#  '155f62a4',
#  '4100',
#  'f5b8c21a',
#  'Bird Measurer (Assessment)_4020',
#  'All Star Sorting_3010',
#  'Scrub-A-Dub_3020',
#  'a44b10dc',
#  'Crystal Caves - Level 1',
#  '1996c610',
#  'ad148f58',
#  '2dc29e21',
#  'Bubble Bath_4020',
#  '736f9581',
#  'c952eb01',
#  '31973d56',
#  '4022',
#  'cf7638f3',
#  'All Star Sorting_2030',
#  '461eace6',
#  'Chow Time_3021',
#  '4c2ec19f',
#  '3110',
#  'Chest Sorter (Assessment)_4020',
#  '7da34a02',
#  '3110_A',
#  'acc_Cauldron Filler (Assessment)',
#  'Pan Balance_2020',
#  '5f0eb72c',
#  '7372e1a5',
#  'Chest Sorter (Assessment)_4025',
#  'Costume Box',
#  'Activity_duration_std',
#  'Dino Dive_3121',
#  '4020',
#  'Cauldron Filler (Assessment)_4035',
#  '3bfd1a65',
#  '0d18d96c',
#  'Air Show_2020',
#  '250513af',
#  'a1e4395d',
#  'Sandcastle Builder (Activity)_4035',
#  'Bubble Bath_3010',
#  'Fireworks (Activity)_3110',
#  'b80e5e84',
#  'Bottle Filler (Activity)_2020',
#  'Egg Dropper (Activity)_2020',
#  'd3268efa',
#  '4030_A',
#  '4090_g',
#  'c51d8688',
#  'Bird Measurer (Assessment)_4070',
#  'Bug Measurer (Activity)_4025',
#  'a76029ee',
#  'ab3136ba',
#  'Bird Measurer (Assessment)_3010',
#  'Chow Time_4035',
#  '1bb5fbdb',
#  'Tree Top City - Level 3',
#  'Bird Measurer (Assessment)_3121',
#  'Chest Sorter (Assessment)_2020',
#  'Rulers_2000',
#  '3121']
